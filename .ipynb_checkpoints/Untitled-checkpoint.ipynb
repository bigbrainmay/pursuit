# %%
from scipy import signal
import numpy as np

# %%
a = np.array([[0, 1], [0, 0]])
b = np.array([[0], [1]])
c = np.array([[1, 0]])
d = np.array([[0]])
sys = signal.StateSpace(a, b, c, d)

# %%
sys
# Out:
# StateSpaceContinuous(
# array([[0, 1],
#        [0, 0]]),
# array([[0],
#        [1]]),
# array([[1, 0]]),
# array([[0]]),
# dt: None
# )
